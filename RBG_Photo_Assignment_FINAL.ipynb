# %% [markdown]
# <a href="https://colab.research.google.com/github/ishitabakshi/DS1002/blob/main/RBG_Photo_Assignment_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import requests

url = input("Please enter the  url of a .jpeg file: ")
image = np.asarray(Image.open(requests.get(url, stream=True).raw))

#covert the image to an NumPy array
image_array = np.array(image)

#create the different channels
def filter_image_red(image_array):
  red_image = image_array.copy()
  red_image[:, :, (1,2)] = 0
  return red_image

def filter_image_green(image_array):
  green_image = image_array.copy()
  green_image[:, :, (0,2)] = 0
  return green_image

def filter_image_blue(image_array):
  blue_image = image_array.copy()
  blue_image[:, :, (0,1)] = 0
  return blue_image

def filter_image_no_blue(image_array):
  no_blue_image = image_array.copy()
  no_blue_image[:, :, (2)] = 0
  return no_blue_image

def filter_image_no_green(image_array):
  no_green_image = image_array.copy()
  no_green_image[:, :, (1)] = 0
  return no_green_image

def filter_image_no_red(image_array):
  no_red_image = image_array.copy()
  no_red_image[:, :, (0)] = 0
  return no_red_image


#filter the image for each channel
red_image = filter_image_red(image_array)
green_image = filter_image_green(image_array)
blue_image = filter_image_blue(image_array)
no_blue_image = filter_image_no_blue(image_array)
no_green_image = filter_image_no_green(image_array)
no_red_image = filter_image_no_red(image_array)

#origional image input
plt.figure(figsize=(5,5))
plt.imshow(image_array)
plt.title('Origional Image')
plt.axis('off')

plt.figure(figsize=(5,5))
plt.imshow(red_image)
plt.title('Red Image')
plt.axis('off')

plt.figure(figsize=(5,5))
plt.imshow(green_image)
plt.title('Green Image')
plt.axis('off')

plt.figure(figsize=(5,5))
plt.imshow(blue_image)
plt.title('Blue Image')
plt.axis('off')

plt.figure(figsize=(5,5))
plt.imshow(no_blue_image)
plt.title('Green and Red Image')
plt.axis('off')

plt.figure(figsize=(5,5))
plt.imshow(no_green_image)
plt.title('Red and Blue Image')
plt.axis('off')

plt.figure(figsize=(5,5))
plt.imshow(no_red_image)
plt.title('Green and Blue Image')
plt.axis('off')

#check to see if the origional image is identitcal to the filtered images
#import cv2

# Load the original image
#original_image = cv2.imread('original_image.jpg')

# Load and merge the red, green, and blue filtered images
#red_filtered_image = cv2.imread('red_filtered_image.jpg')
#green_filtered_image = cv2.imread('green_filtered_image.jpg')
#blue_filtered_image = cv2.imread('blue_filtered_image.jpg')
#combined_image = cv2.merge([blue_filtered_image, green_filtered_image, red_filtered_image])

# Check if the images are identical
#if original_image.shape == combined_image.shape and (original_image == combined_image).all():
    #print("The images are identical.")
#else:
    #print("The images are not identical.")
# Out:
# Please enter the  url of a .jpeg file: https://t3.ftcdn.net/jpg/06/10/68/10/360_F_610681083_M6XlAUkKj0I9ykA0Iz1ysOTCsNvpU5Vw.jpg
# (-0.5, 539.5, 359.5, -0.5)

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import requests

#request the input of an image
url = input("Please enter the  url of a .jpeg file: ")
image = np.asarray(Image.open(requests.get(url, stream=True).raw))

#covert the image to an NumPy array
image_array = np.array(image)

#create the different channels using definitions
def filter_image_red(image_array):
  red_image = image_array.copy()
  red_image[:, :, (1,2)] = 0
  return red_image

def filter_image_green(image_array):
  green_image = image_array.copy()
  green_image[:, :, (0,2)] = 0
  return green_image

def filter_image_blue(image_array):
  blue_image = image_array.copy()
  blue_image[:, :, (0,1)] = 0
  return blue_image

def filter_image_no_blue(image_array):
  no_blue_image = image_array.copy()
  no_blue_image[:, :, (2)] = 0
  return no_blue_image

def filter_image_no_green(image_array):
  no_green_image = image_array.copy()
  no_green_image[:, :, (1)] = 0
  return no_green_image

def filter_image_no_red(image_array):
  no_red_image = image_array.copy()
  no_red_image[:, :, (0)] = 0
  return no_red_image


#filter the image for each channel
red_image = filter_image_red(image_array)
green_image = filter_image_green(image_array)
blue_image = filter_image_blue(image_array)
no_blue_image = filter_image_no_blue(image_array)
no_green_image = filter_image_no_green(image_array)
no_red_image = filter_image_no_red(image_array)

#origional image input
plt.figure(figsize=(5,5))
plt.imshow(image_array)
plt.title('Origional Image')
plt.axis('off')

#imput of the filtered images
plt.figure(figsize=(5,5))
plt.imshow(red_image)
plt.title('Red Image')
plt.axis('off')

plt.figure(figsize=(5,5))
plt.imshow(green_image)
plt.title('Green Image')
plt.axis('off')

plt.figure(figsize=(5,5))
plt.imshow(blue_image)
plt.title('Blue Image')
plt.axis('off')

plt.figure(figsize=(5,5))
plt.imshow(no_blue_image)
plt.title('Green and Red Image')
plt.axis('off')

plt.figure(figsize=(5,5))
plt.imshow(no_green_image)
plt.title('Red and Blue Image')
plt.axis('off')

plt.figure(figsize=(5,5))
plt.imshow(no_red_image)
plt.title('Green and Blue Image')
plt.axis('off')
# Out:
# Please enter the  url of a .jpeg file: https://s3.amazonaws.com/eit-planttoolbox-prod/media/images/Bellis_Perennis--Morgaine--CC_BY_2.0.jpg
# (-0.5, 499.5, 332.5, -0.5)
